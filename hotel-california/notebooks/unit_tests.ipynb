# %%
import logging
from typing import Any, Dict, Tuple
import numpy as np
import pandas as pd
import great_expectations as gx
import mlflow

import os
from pathlib import Path
# Path
raw_data_dir = Path("/Users/antoniooliveira/Documents/GitHub/mlops_project_v2/hotel-california/data/01_raw")
# Change working directory
os.chdir(raw_data_dir)

# %%
df = pd.read_csv('X_train.csv')
df
# Out:
#        BookingID  ArrivalYear  ArrivalMonth  ArrivalWeekNumber  \
# 0          10423         2016             3                 13
# 1          14038         2016             4                 17
# 2          37179         2016            12                 53
# 3          15019         2016             4                 18
# 4          30385         2016             5                 21
# ...          ...          ...           ...                ...
# 11145      12808         2016            10                 44
# 11146      34022         2016            10                 44
# 11147      30472         2016             4                 18
# 11148      20119         2016             7                 30
# 11149      32885         2016             9                 40
#
#        ArrivalDayOfMonth  ArrivalHour  WeekendStays  WeekdayStays  Adults  \
# 0                     21        18.00             1             2       2
# 1                     23        16.00             2             4       2
# 2                     28        16.00             0             1       2
# 3                     30        15.25             2             5       2
# 4                     17        15.50             0             2       2
# ...                  ...          ...           ...           ...     ...
# 11145                 29        17.50             2             1       2
# 11146                 26        17.25             0             2       1
# 11147                 28        17.25             0             2       2
# 11148                 20        21.50             0             2       2
# 11149                 25        16.00             2             2       2
#
#        Children  ...  CompanyReservation  OrderedMealsPerDay  FloorReserved  \
# 0           0.0  ...                   1                   1              6
# 1           2.0  ...                   1                   1              1
# 2           0.0  ...                   1                   1              6
# 3           0.0  ...                   1                   1              6
# 4           0.0  ...                   1                   1              6
# ...         ...  ...                 ...                 ...            ...
# 11145       0.0  ...                   1                   1              6
# 11146       0.0  ...                   1                   1              6
# 11147       0.0  ...                   1                   1              6
# 11148       1.0  ...                   1                   1              6
# 11149       0.0  ...                   1                   1              6
#
#        FloorAssigned  DailyRateEuros  DailyRateUSD  %PaidinAdvance  \
# 0                  3           85.00       84.1500             0.0
# 1                  1          206.00      203.9400             0.0
# 2                  6          138.00      136.6200             0.0
# 3                  6          109.81      108.7119             0.0
# 4                  5          140.00      138.6000             0.0
# ...              ...             ...           ...             ...
# 11145              6           90.90       89.9910             0.0
# 11146              6          130.00      128.7000             0.0
# 11147              6          111.60      110.4840             0.0
# 11148              3          126.00      124.7400             0.0
# 11149              6          158.00      156.4200             0.0
#
#        CountryofOriginAvgIncomeEuros (Year-2)  \
# 0                                    40141.59
# 1                                     7199.25
# 2                                    28742.44
# 3                                    28742.44
# 4                                    28742.44
# ...                                       ...
# 11145                                36194.87
# 11146                                28742.44
# 11147                                47011.55
# 11148                                28742.44
# 11149                                33525.74
#
#        CountryofOriginAvgIncomeEuros (Year-1)  CountryofOriginHDI (Year-1)
# 0                                    40833.24                        0.898
# 1                                     7096.60                        0.572
# 2                                    29668.86                        0.842
# 3                                    29668.86                        0.842
# 4                                    29668.86                        0.842
# ...                                       ...                          ...
# 11145                                36909.33                        0.876
# 11146                                29668.86                        0.842
# 11147                                47683.79                        0.933
# 11148                                29668.86                        0.842
# 11149                                34912.48                        0.885
#
# [11150 rows x 33 columns]

# %%
def unit_test(data: pd.DataFrame):

    if mlflow.active_run():
        mlflow.end_run()

    df=data.copy(deep=True)

    mlflow.set_experiment("data_unit_tests")

    with mlflow.start_run(run_name="verify_data_quality") as run:
        mlflow.set_tag("mlflow.runName", "verify_data_quality")
    
        # Log the raw data statistics
        describe_to_dict=df.describe().to_dict()
        mlflow.log_dict(describe_to_dict,"describe_data_raw.json")

        pd_df_gx = gx.dataset.PandasDataset(df)

        # Check that BookingID is a number (integer )
        assert pd_df_ge.expect_column_values_to_be_of_type(
            'BookingID', type_='int64' 
        ).success == True

# %%
unit_test(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 unit_test(df)
#
# Cell In[14], line 17, in unit_test(data)
#      14 describe_to_dict=df.describe().to_dict()
#      15 mlflow.log_dict(describe_to_dict,"describe_data_raw.json")
# ---> 17 pd_df_gx = gx.dataset.PandasDataset(df)
#      19 # Check that BookingID is a number (integer )
#      20 assert pd_df_ge.expect_column_values_to_be_of_type(
#      21     'BookingID', type_='int64'
#      22 ).success == True
#
# AttributeError: module 'great_expectations' has no attribute 'dataset'

# %%
# %pip uninstall mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-3.1.0-py3-none-any.whl.metadata (29 kB)
# Collecting mlflow-skinny==3.1.0 (from mlflow)
#   Downloading mlflow_skinny-3.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting Flask<4 (from mlflow)
#   Using cached flask-3.1.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.16.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Using cached graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Using cached gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: matplotlib<4 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow) (2.1.4)
# Requirement already satisfied: pyarrow<21,>=4.0.0 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow) (20.0.0)
# Collecting scikit-learn<2 (from mlflow)
#   Downloading scikit_learn-1.7.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: scipy<2 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow) (2.0.41)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow) (8.1.8)
# Collecting cloudpickle<4 (from mlflow-skinny==3.1.0->mlflow)
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.1.0->mlflow)
#   Downloading databricks_sdk-0.57.0-py3-none-any.whl.metadata (39 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.1.0->mlflow)
#   Downloading fastapi-0.115.13-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow) (8.7.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.1.0->mlflow)
#   Downloading opentelemetry_api-1.34.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.1.0->mlflow)
#   Downloading opentelemetry_sdk-1.34.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging<26 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow) (6.31.1)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow) (2.11.7)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow) (2.32.4)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.1.0->mlflow)
#   Using cached sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow) (4.14.0)
# Collecting uvicorn<1 (from mlflow-skinny==3.1.0->mlflow)
#   Downloading uvicorn-0.34.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: google-auth~=2.0 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->mlflow) (2.40.3)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.1.0->mlflow)
#   Using cached starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from Flask<4->mlflow) (3.0.2)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.1.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.1.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->mlflow) (4.9.1)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.1.0->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow) (3.2.3)
# Collecting opentelemetry-semantic-conventions==0.55b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.1.0->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.0->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.0->mlflow) (0.4.1)
# Requirement already satisfied: six>=1.5 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.0->mlflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.0->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.1.0->mlflow) (2025.6.15)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->mlflow) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from scikit-learn<2->mlflow) (1.5.1)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<2->mlflow)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: greenlet>=1 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.3)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.0->mlflow) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.0->mlflow) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /Users/antoniooliveira/Documents/GitHub/mlops_project_v2/.venv/lib/python3.11/site-packages (from uvicorn<1->mlflow-skinny==3.1.0->mlflow) (0.16.0)
# Downloading mlflow-3.1.0-py3-none-any.whl (24.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 9.3 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Downloading mlflow_skinny-3.1.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 9.3 MB/s eta 0:00:00
# Downloading alembic-1.16.2-py3-none-any.whl (242 kB)
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading databricks_sdk-0.57.0-py3-none-any.whl (733 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.8/733.8 kB 7.1 MB/s eta 0:00:00
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.115.13-py3-none-any.whl (95 kB)
# Using cached flask-3.1.1-py3-none-any.whl (103 kB)
# Using cached graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Using cached graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading opentelemetry_api-1.34.1-py3-none-any.whl (65 kB)
# Downloading opentelemetry_sdk-1.34.1-py3-none-any.whl (118 kB)
# Downloading opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl (196 kB)
# Downloading scikit_learn-1.7.0-cp311-cp311-macosx_10_9_x86_64.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 10.4 MB/s eta 0:00:0031m10.8 MB/s eta 0:00:01
# Using cached sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Using cached starlette-0.46.2-py3-none-any.whl (72 kB)
# Downloading uvicorn-0.34.3-py3-none-any.whl (62 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached mako-1.3.10-py3-none-any.whl (78 kB)
# Installing collected packages: werkzeug, uvicorn, threadpoolctl, sqlparse, Mako, itsdangerous, gunicorn, graphql-core, cloudpickle, blinker, starlette, scikit-learn, opentelemetry-api, graphql-relay, Flask, docker, alembic, opentelemetry-semantic-conventions, graphene, fastapi, databricks-sdk, opentelemetry-sdk, mlflow-skinny, mlflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24/24 [mlflow]m━ 23/24 [mlflow]mlflow-skinny]entions]
# Successfully installed Flask-3.1.1 Mako-1.3.10 alembic-1.16.2 blinker-1.9.0 cloudpickle-3.1.1 databricks-sdk-0.57.0 docker-7.1.0 fastapi-0.115.13 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 itsdangerous-2.2.0 mlflow-3.1.0 mlflow-skinny-3.1.0 opentelemetry-api-1.34.1 opentelemetry-sdk-1.34.1 opentelemetry-semantic-conventions-0.55b1 scikit-learn-1.7.0 sqlparse-0.5.3 starlette-0.46.2 threadpoolctl-3.6.0 uvicorn-0.34.3 werkzeug-3.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
def unit_test(data: pd.DataFrame,): 

    if mlflow.active_run():
        mlflow.end_run()

    df=data.copy(deep=True)

    mlflow.set_experiment("data_unit_tests")

    with mlflow.start_run(run_name="verify_data_quality") as run:
        mlflow.set_tag("mlflow.runName", "verify_data_quality")
    
        # Log the raw data statistics
        describe_to_dict=df.describe().to_dict()
        mlflow.log_dict(describe_to_dict,"describe_data_raw.json")
    
        # Perform data quality checks using Great Expectations
        pd_df_ge = ge.from_pandas(df)
        assert pd_df_ge.expect_column_values_to_be_between('product_weight_g', min_value=0, max_value=50000, mostly=0.75).success == True
        assert pd_df_ge.expect_column_values_to_not_be_null('product_weight_g').success == False
        assert pd_df_ge.expect_column_values_to_be_between('product_length_cm', min_value=5, max_value=150, mostly=0.75).success == True
        assert pd_df_ge.expect_column_values_to_not_be_null('product_length_cm').success == False
        assert pd_df_ge.expect_column_values_to_be_between('product_width_cm', min_value=5, max_value=110, mostly=0.75).success == True
        assert pd_df_ge.expect_column_values_to_not_be_null('product_width_cm').success == False
        assert pd_df_ge.expect_column_values_to_be_between('product_height_cm', min_value=5, max_value=110, mostly=0.75).success == True
        assert pd_df_ge.expect_column_values_to_not_be_null('product_height_cm').success == False
        assert pd_df_ge.expect_column_to_exist('order_status').success == True
        assert pd_df_ge.expect_column_values_to_not_be_null('order_status').success == True
        assert pd_df_ge.expect_column_to_exist('price').success == True
        assert pd_df_ge.expect_column_values_to_not_be_null('customer_id').success == True
        assert pd_df_ge.expect_column_values_to_not_be_null('product_category_name').success == False
        assert pd_df_ge.expect_column_values_to_be_in_set("order_status", ['delivered', 'shipped', 'processing', 'canceled', 'invoiced', 'unavailable', 'approved']).success == False
        assert pd_df_ge.expect_column_values_to_be_in_type_list("customer_id", ["int", "int64"]).success == True
        
         # Log the cleaned data statistics
        describe_to_dict=df.describe().to_dict()
        mlflow.log_dict(describe_to_dict,"describe_data_cleaned.json")
    mlflow.end_run()


    log = logging.getLogger(__name__)
    log.info("Data passed on the unit data tests")

    return 0
